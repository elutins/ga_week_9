# %% [markdown]
# # Introduction to Datetime with Pandas
#
#
# ## Framing
#
# This week we'll be working with time and space data. This lesson will focus on the basics of manipulating time data in python. You may have had some experience working with time data in the West Nile Virus thorugh trying to match weather data with trap inspection dates.  What are some other potential uses of time data?

# %% [markdown]
# <img src="https://media.giphy.com/media/nONbcdJqgP4NG/giphy.gif"/>

# %% [markdown]
# ## Lesson Outline
#
# - Introduce/Review Datetime Functions in Pandas
# - Generate plots with timedata
# - Introduce common datetime functions:
#
#
# ## Objectives:
#
# By the end of this lesson, students will be able to:
#
# - Define and utilize the following datetime functions
#     - Resampling
#     - Autocorrelation
#     - Rolling Mean
#     - Explonential Mean
#     - Diff
#     - Expanding Functions

# %% [markdown]
# # Datetime with Pandas
#
# ![pandas time!](https://s-media-cache-ak0.pinimg.com/originals/c2/65/44/c2654482bb9711cbd0cc4b5b7111f66e.jpg)
#
#
# Pandas started out in the financial industry (specifically at AQR Capital Management in 2008), which is why it's so great at everything related to timeseries.

# %% [markdown]
# ## Part 1: Datetime Object

# %%
# The date time library is something you should already have because of Anaconda.
from datetime import datetime


# Let's look at the date we once believed the world would end on.
lesson_date = datetime(2012, 12, 21, 12, 21, 12, 844089)

# %%
lesson_date
# Out:
# datetime.datetime(2012, 12, 21, 12, 21, 12, 844089)

# %%
# elements within lesson_date
print "Micro-Second", lesson_date.microsecond
print "Second", lesson_date.second
print "Minute", lesson_date.minute
print "Hour", lesson_date.hour
print "Day", lesson_date.day
print "Month",lesson_date.month
print "Year", lesson_date.year
# Out:
# Micro-Second 844089
# Second 12
# Minute 21
# Hour 12
# Day 21
# Month 12
# Year 2012

# %% [markdown]
# ## Timedelta
# Say we want to add or subtract time to/from a date. Perhaps we're using time as an index and we want to get everything that happened a week before a specific observation, for example.
#
# We can use a timedelta object to shift a Datetime object. Here's an example:

# %%
# Import timedelta from datetime library
from datetime import timedelta

# Time deltas represent time as an amount as opposed to a fixed position.
offset = timedelta(days=1, seconds=20)

# the time delta has attributes that allow us to extract values from it.
print 'offset days', offset.days
print 'offset seconds', offset.seconds
print 'offset microseconds', offset.microseconds
# Out:
# offset days 1
# offset seconds 20
# offset microseconds 0

# %%
now = datetime.now()
print "It's now: ", now
# Out:
# It's now:  2017-08-14 14:07:55.694837

# %%
print "Future: ", now + offset
print "Past: ", now - offset
# Out:
# Future:  2017-08-15 14:08:15.694837
# Past:  2017-08-13 14:07:35.694837

# %% [markdown]
# Note: The largest value a time delta can hold is 'Days'.  I.e. you can't say you want you an offset to be 2 years, 44 days and 12 hours.  You would have to manually convert the time of those years to be represented in days.

# %%
# Get a dataset from the internets
import pandas as pd
ufo = pd.read_csv('http://bit.ly/uforeports')

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
# We can see that the Time column is just an object.
ufo.dtypes
# Out:
# City               object
# Colors Reported    object
# Shape Reported     object
# State              object
# Time               object
# dtype: object

# %%
#Overwrite the original Time column with one that has been converted to a datetime series.
ufo['Time'] = pd.to_datetime(ufo.Time)

#Letting pandas guess how to do this can take a little bit of time we can use a few arguments to help.
'''ufo['Time'] = pd.to_datetime(ufo.Time, format='%Y%m%d', errors='coerce')'''
# Format will let pandas know what format pandas should use to interpret the date as
# errors will allow you to automatically deal with errors when converting.
# Out:
# "ufo['Time'] = pd.to_datetime(ufo.Time, format='%Y%m%d', errors='coerce')"

# %%
#the time column looks a bit different now!
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time
# 0 1930-06-01 22:00:00
# 1 1930-06-30 20:00:00
# 2 1931-02-15 14:00:00
# 3 1931-06-01 13:00:00
# 4 1933-04-18 19:00:00

# %%
#let's take a look at how the series has changed
ufo.dtypes
# Out:
# City                       object
# Colors Reported            object
# Shape Reported             object
# State                      object
# Time               datetime64[ns]
# dtype: object

# %%
# we can also use dt to get weekday names 
ufo.Time.dt.weekday_name.head()
# Out:
# 0     Sunday
# 1     Monday
# 2     Sunday
# 3     Monday
# 4    Tuesday
# Name: Time, dtype: object

# %%
#and what day of the year it was!
ufo.Time.dt.dayofyear.head()
# Out:
# 0    152
# 1    181
# 2     46
# 3    152
# 4    108
# Name: Time, dtype: int64

# %%
ufo['weekend'] = [1 if x.weekday()>4 else 0 for x in ufo['Time']]

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time  weekend
# 0 1930-06-01 22:00:00        1
# 1 1930-06-30 20:00:00        0
# 2 1931-02-15 14:00:00        1
# 3 1931-06-01 13:00:00        0
# 4 1933-04-18 19:00:00        0

# %% [markdown]
# #### Independent activity:
# Take 10 minutes to look at the different ways you can work with timezones and timezone formatting. Try creating a few new columns for things like daylight savings adjustment, timezone name, etc.
#
# https://docs.python.org/2/library/datetime.html

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time  weekend
# 0 1930-06-01 22:00:00        1
# 1 1930-06-30 20:00:00        0
# 2 1931-02-15 14:00:00        1
# 3 1931-06-01 13:00:00        0
# 4 1933-04-18 19:00:00        0

# %% [markdown]
# ## Time Stamps

# %%
#let's create a timestamp of interest
ts = pd.to_datetime('9/10/1993')
#^that's the day x-files first came out, for all of you wondering
ts
# The main difference between a Datetime object and a timestamp is...
# that timestamps can be used as comparisions.
# Out:
# Timestamp('1993-09-10 00:00:00')

# %%
# Use the timestamp we just saved to create a new dataframe.
ufo.loc[ufo.Time >= ts, :].head()
# Out:
#           City Colors Reported Shape Reported State                Time  \
# 7190   Phoenix             NaN      RECTANGLE    AZ 1993-09-10 20:30:00
# 7191  Chicopee             NaN       TRIANGLE    MA 1993-09-10 22:30:00
# 7192     Milan             NaN       TRIANGLE    OH 1993-09-11 21:11:00
# 7193      Yuma             NaN       TRIANGLE    AZ 1993-09-13 21:30:00
# 7194    Toledo     ORANGE BLUE           OVAL    OH 1993-09-14 21:00:00
#
#       weekend
# 7190        0
# 7191        0
# 7192        1
# 7193        0
# 7194        0

# %%
#we could create a new column looking at how far away from our point of interest a particular UFO was sighted
ufo['new'] = ufo.Time - ts

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time  weekend                   new
# 0 1930-06-01 22:00:00        1 -23112 days +22:00:00
# 1 1930-06-30 20:00:00        0 -23083 days +20:00:00
# 2 1931-02-15 14:00:00        1 -22853 days +14:00:00
# 3 1931-06-01 13:00:00        0 -22747 days +13:00:00
# 4 1933-04-18 19:00:00        0 -22060 days +19:00:00

# %%
ufo.tail()
# Out:
#               City Colors Reported Shape Reported State                Time  \
# 18236   Grant Park             NaN       TRIANGLE    IL 2000-12-31 23:00:00
# 18237  Spirit Lake             NaN           DISK    IA 2000-12-31 23:00:00
# 18238  Eagle River             NaN            NaN    WI 2000-12-31 23:45:00
# 18239  Eagle River             RED          LIGHT    WI 2000-12-31 23:45:00
# 18240         Ybor             NaN           OVAL    FL 2000-12-31 23:59:00
#
#        weekend                new
# 18236        1 2669 days 23:00:00
# 18237        1 2669 days 23:00:00
# 18238        1 2669 days 23:45:00
# 18239        1 2669 days 23:45:00
# 18240        1 2669 days 23:59:00

# %%
# Timedelta can also be used to get the min and max of a timeseries.
ufo.Time.max() - ufo.Time.min()
# Out:
# Timedelta('25781 days 01:59:00')

# %% [markdown]
# You can also use timedelta to mess around with the silly YouTube videos you're embedding in a notebook

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("hAAlDoAtV7Y")

# %%
start=int(timedelta(minutes=1, seconds=2).total_seconds())
YouTubeVideo("hAAlDoAtV7Y", start=start, autoplay=1, theme="light", color="red")

# %% [markdown]
# #### More independent work:
#
# Search for .dt. on http://pandas.pydata.org/pandas-docs/stable/api.html for more information about pandas Datetime.

# %% [markdown]
# ## Plotting a timeseries using pandas

# %%
#let's load in a different dataset
crime = pd.read_csv('https://raw.githubusercontent.com/rufuspollock/crime-data-sf/gh-pages/data/sfpd_incidents_march_2012.tidied.csv')

# %%
#taking a look at our different types
crime.dtypes
# Out:
# IncidntNum      int64
# Category       object
# Descript       object
# DayOfWeek      object
# Date           object
# Time           object
# PdDistrict     object
# Resolution     object
# Address        object
# X             float64
# Y             float64
# Location       object
# dtype: object

# %%
#so do we want to mess around with the date or the time?
crime.head()
# Out:
#    IncidntNum        Category                               Descript  \
# 0   120168291    NON-CRIMINAL                        COURTESY REPORT
# 1   120170901         ROBBERY                  ROBBERY, BODILY FORCE
# 2   120170917         ASSAULT            INFLICT INJURY ON COHABITEE
# 3   120170945  OTHER OFFENSES  DRIVERS LICENSE, SUSPENDED OR REVOKED
# 4   120170951        BURGLARY      BURGLARY OF STORE, FORCIBLE ENTRY
#
#   DayOfWeek                       Date   Time  PdDistrict      Resolution  \
# 0  Thursday  03/01/2012 08:00 AM +0000  06:50  TENDERLOIN            NONE
# 1  Thursday  03/01/2012 08:00 AM +0000  00:10  TENDERLOIN            NONE
# 2  Thursday  03/01/2012 08:00 AM +0000  00:01   INGLESIDE  ARREST, BOOKED
# 3  Thursday  03/01/2012 08:00 AM +0000  01:00  TENDERLOIN   ARREST, CITED
# 4  Thursday  03/01/2012 08:00 AM +0000  00:29    RICHMOND            NONE
#
#                  Address           X          Y  \
# 0    0 Block of JONES ST -122.412120  37.780904
# 1  300 Block of MASON ST -122.409737  37.787152
# 2     0 Block of 30TH ST -122.422691  37.742298
# 3   POWELL ST / ELLIS ST -122.407854  37.785492
# 4  800 Block of GREAT HY -122.511137  37.772922
#
#                               Location
# 0  37.7809035011582, -122.412119695795
# 1  37.7871515174923, -122.409736977824
# 2   37.742298340459, -122.422690779386
# 3  37.7854922044602, -122.407854234538
# 4  37.7729219403249, -122.511137153422

# %%
#let's turn date into a datetime object
crime['Date'] = pd.to_datetime(crime.Date)

# %%
crime.tail()
# Out:
#       IncidntNum        Category                               Descript  \
# 9531   126049132       VANDALISM          MALICIOUS MISCHIEF, VANDALISM
# 9532   126049148   LARCENY/THEFT           GRAND THEFT FROM LOCKED AUTO
# 9533   126049160       VANDALISM          MALICIOUS MISCHIEF, VANDALISM
# 9534   126051739   LARCENY/THEFT                PETTY THEFT OF PROPERTY
# 9535   129000260  OTHER OFFENSES  DRIVERS LICENSE, SUSPENDED OR REVOKED
#
#       DayOfWeek                Date   Time PdDistrict Resolution  \
# 9531  Wednesday 2012-03-21 07:00:00  23:25    MISSION       NONE
# 9532   Thursday 2012-03-22 07:00:00  19:00    MISSION       NONE
# 9533    Tuesday 2012-03-20 07:00:00  20:00    MISSION       NONE
# 9534   Saturday 2012-03-17 07:00:00  20:00    CENTRAL       NONE
# 9535   Thursday 2012-03-29 07:00:00  10:12    TARAVAL       NONE
#
#                           Address           X          Y  \
# 9531          15TH ST / FOLSOM ST -122.415464  37.766937
# 9532  100 Block of CHATTANOOGA ST -122.426570  37.753858
# 9533       600 Block of CHURCH ST -122.428488  37.761196
# 9534       COLUMBUS AV / GREEN ST -122.409017  37.799488
# 9535          CRESPI DR / 19TH AV -122.475223  37.720442
#
#                                  Location
# 9531  37.7669370292874, -122.415464372874
# 9532  37.7538576053338, -122.426569974378
# 9533  37.7611960721483, -122.428488113841
# 9534  37.7994880717633, -122.409017007613
# 9535  37.7204418078734, -122.475223128467

# %%
#I'm arbitrarily picking weekday to be how we look at our data
crime['weekday'] = crime.Date.dt.weekday

# %%
#let's groupby weekday on this 
crime_ts = crime.groupby('weekday').aggregate(len)['IncidntNum']
#the groupby statement automatically makes weekday the index

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

plt.plot(crime_ts.index, crime_ts.values, lw=5)
#LW = line width!
#a small stringed instrument! a classical timeseries!

# %% [markdown]
# ### Note: When working with datetime data, it is often best to convert that column to an index

# %%
#let's convert the date to be the index
crime.set_index('Date', inplace=True)

# %%
crime['Month'] = crime.index.month
crime['weekday'] = crime.index.weekday

# %%
#filtering by date becomes really easy when you're working with it as an index!

crime['2012-03-04']
# Out:
#                      IncidntNum                Category  \
# Date
# 2012-03-04 08:00:00   120179969                BURGLARY
# 2012-03-04 08:00:00   120179163          OTHER OFFENSES
# 2012-03-04 08:00:00   120179969          OTHER OFFENSES
# 2012-03-04 08:00:00   120179969          OTHER OFFENSES
# 2012-03-04 08:00:00   120179969          OTHER OFFENSES
# 2012-03-04 08:00:00   120180041          OTHER OFFENSES
# 2012-03-04 08:00:00   120180182          OTHER OFFENSES
# 2012-03-04 08:00:00   120180182          OTHER OFFENSES
# 2012-03-04 08:00:00   120180251                 ASSAULT
# 2012-03-04 08:00:00   120180251          OTHER OFFENSES
# 2012-03-04 08:00:00   120180251          OTHER OFFENSES
# 2012-03-04 08:00:00   120180364                BURGLARY
# 2012-03-04 08:00:00   120180364                BURGLARY
# 2012-03-04 08:00:00   120180364          OTHER OFFENSES
# 2012-03-04 08:00:00   120180433          OTHER OFFENSES
# 2012-03-04 08:00:00   120180455          OTHER OFFENSES
# 2012-03-04 08:00:00   120180596          OTHER OFFENSES
# 2012-03-04 08:00:00   120180988                WARRANTS
# 2012-03-04 08:00:00   120181334                BURGLARY
# 2012-03-04 08:00:00   120181334  FORGERY/COUNTERFEITING
# 2012-03-04 08:00:00   120181588           DRUG/NARCOTIC
# 2012-03-04 08:00:00   120181588           DRUG/NARCOTIC
# 2012-03-04 08:00:00   120181641           DRUG/NARCOTIC
# 2012-03-04 08:00:00   120181641                WARRANTS
# 2012-03-04 08:00:00   120181710           DRUG/NARCOTIC
# 2012-03-04 08:00:00   120181710           DRUG/NARCOTIC
# 2012-03-04 08:00:00   120181710          OTHER OFFENSES
# 2012-03-04 08:00:00   120181801           DRUG/NARCOTIC
# 2012-03-04 08:00:00   120181801           DRUG/NARCOTIC
# 2012-03-04 08:00:00   120181845           DRUG/NARCOTIC
# ...                         ...                     ...
# 2012-03-04 08:00:00   120180825                BURGLARY
# 2012-03-04 08:00:00   120180825           LARCENY/THEFT
# 2012-03-04 08:00:00   126033533               VANDALISM
# 2012-03-04 08:00:00   120180869           VEHICLE THEFT
# 2012-03-04 08:00:00   120182081           VEHICLE THEFT
# 2012-03-04 08:00:00   120182451           VEHICLE THEFT
# 2012-03-04 08:00:00   120199315          OTHER OFFENSES
# 2012-03-04 08:00:00   120187445           VEHICLE THEFT
# 2012-03-04 08:00:00   120180706                BURGLARY
# 2012-03-04 08:00:00   120183261           VEHICLE THEFT
# 2012-03-04 08:00:00   120189435                TRESPASS
# 2012-03-04 08:00:00   120214032           LARCENY/THEFT
# 2012-03-04 08:00:00   120225829                 ROBBERY
# 2012-03-04 08:00:00   120182445          MISSING PERSON
# 2012-03-04 08:00:00   120186196          MISSING PERSON
# 2012-03-04 08:00:00   120180148                 ASSAULT
# 2012-03-04 08:00:00   120180148                 ASSAULT
# 2012-03-04 08:00:00   120180148                 ASSAULT
# 2012-03-04 08:00:00   120182207          MISSING PERSON
# 2012-03-04 08:00:00   126033317           LARCENY/THEFT
# 2012-03-03 08:00:00  37.7830146033793, -122.414057981709        5      3
# ...                                                  ...      ...    ...
# 2012-03-04 08:00:00  37.7463649495382, -122.419436540611        6      3
# 2012-03-04 08:00:00  37.7633751487565, -122.406180125805        6      3
# 2012-03-03 08:00:00  37.7538222149764, -122.430281172982        5      3
# 2012-03-04 08:00:00  37.7752316978114, -122.403742962696        6      3
# 2012-03-03 08:00:00  37.7670824029841, -122.407685897302        5      3
# 2012-03-03 08:00:00  37.7621365231213, -122.436242962986        5      3
# 2012-03-03 08:00:00  37.7743581710701, -122.420254960348        5      3
# 2012-03-03 08:00:00  37.7341354528782, -122.475993694939        5      3
# 2012-03-03 08:00:00  37.7833120131171, -122.432668405006        5      3
# 2012-03-03 08:00:00  37.7878380173293, -122.403126181258        5      3
# 2012-03-04 08:00:00  37.8007193854313, -122.410581504404        6      3
# 2012-03-04 08:00:00  37.7752316978114, -122.403742962696        6      3
# 2012-03-04 08:00:00  37.7756784107014, -122.442883849877        6      3
# 2012-03-03 08:00:00  37.7602597796836, -122.462966382413        5      3
# 2012-03-03 08:00:00  37.7809557775891, -122.413710613918        5      3
# 2012-03-03 08:00:00  37.7837931670446, -122.483882676574        5      3
# 2012-03-03 08:00:00  37.7837931670446, -122.483882676574        5      3
# 2012-03-04 08:00:00  37.7776675641046, -122.413089923554        6      3
# 2012-03-03 08:00:00  37.8008632290062, -122.437480015002        5      3
# 2012-03-04 08:00:00  37.7649620272423, -122.419802080745        6      3
# 2012-03-04 08:00:00  37.7649620272423, -122.419802080745        6      3
# 2012-03-04 08:00:00  37.7649620272423, -122.419802080745        6      3
# 2012-03-04 08:00:00  37.7649620272423, -122.419802080745        6      3
# 2012-03-04 08:00:00  37.7649620272423, -122.419802080745        6      3
# 2012-03-03 08:00:00  37.7482179227912, -122.410586190639        5      3
# 2012-03-03 08:00:00  37.7482179227912, -122.410586190639        5      3
# 2012-03-03 08:00:00   37.778984045697, -122.437697207772        5      3
# 2012-03-03 08:00:00  37.7857918644545, -122.442228350919        5      3
# 2012-03-04 08:00:00  37.7340152180723, -122.390971734551        6      3
# 2012-03-03 08:00:00  37.7124493643675, -122.418469921971        5      3
#
# [662 rows x 13 columns]

# %% [markdown]
# ## Part 2: Introduction to autocorrelation and window functions

# %%
#For this example will be working with sales data. This is a big dataset, so it might take a minute...
url = 'https://raw.githubusercontent.com/sinanuozdemir/sfdat22/master/data/rossmann.csv'
data = pd.read_csv(url, skipinitialspace=True, low_memory=False)
import seaborn as sns

# %%
data.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
# Most interested in date - format properly and convert to index
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)

# %%
# create new columns for year and month 
data['Year'] = data.index.year
data['Month'] = data.index.month

data.head()
# Out:
#             Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# Date
# 2015-07-31      1          5   5263        555     1      1            0
# 2015-07-31      2          5   6064        625     1      1            0
# 2015-07-31      3          5   8314        821     1      1            0
# 2015-07-31      4          5  13995       1498     1      1            0
# 2015-07-31      5          5   4822        559     1      1            0
#
#             SchoolHoliday  Year  Month
# Date
# 2015-07-31              1  2015      7
# 2015-07-31              1  2015      7
# 2015-07-31              1  2015      7
# 2015-07-31              1  2015      7
# 2015-07-31              1  2015      7

# %%
# There are over a million sales data points in this dataset, so for some simple EDA we will focus on just one store.
store1_data = data[data.Store == 1]
store1_data.head()
# Out:
#             Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# Date
# 2015-07-31      1          5   5263        555     1      1            0
# 2015-07-30      1          4   5020        546     1      1            0
# 2015-07-29      1          3   4782        523     1      1            0
# 2015-07-28      1          2   5011        560     1      1            0
# 2015-07-27      1          1   6102        612     1      1            0
#
#             SchoolHoliday  Year  Month
# Date
# 2015-07-31              1  2015      7
# 2015-07-30              1  2015      7
# 2015-07-29              1  2015      7
# 2015-07-28              1  2015      7
# 2015-07-27              1  2015      7

# %% [markdown]
# As we begin to study the sales from this drugstore, we also want to know both the time dependent elements of sales as well as whether promotions or holidays effected these sales. To start, we can compare the average sales on those events.
#
# To compare sales on holidays, we can compare the sales using box-plots, which allows us to compare the distribution of sales on holidays against all other days. On state holidays the store is closed (which means there are 0 sales), and
# on school holidays the sales are relatively similar. These types of insights represent the contextual knowledge needed
# to truly explain time series phenomenon. Can you think of any other special considerations we should make when tracking sales?

# %%
# check similarity between School Holiday and Sales
sns.factorplot(
    x='SchoolHoliday',
    y='Sales',
    data=store1_data,
    kind='box'
)

# %%
#  We can see that there is a difference in sales on promotion days
sns.factorplot(
    col='Open',
    x='Promo',
    y='Sales',
    data=store1_data,
    kind='box'
)

# %% [markdown]
# Why is it important to separate out days where the store is closed? Because there aren't any promotions on those days either, so including them will bias your sales data on days without promotions!
#
# Remember: Data Scientists needs to think about the business logic (context) as well as analyzing the raw data.

# %%
# perhaps plot sales across day of the week
sns.factorplot(
    col='Open',
    x='DayOfWeek',
    y='Sales',
    data=store1_data,
    kind='box',
)

# %%
# Consider sales across multiple years. How did sales change from 2014 to 2015?

# Filter to days store 1 was open
store1_open_data = store1_data[store1_data.Open==1]
store1_open_data[['Sales']].plot()          # sales over time
store1_open_data[['Customers']].plot()      # customers over time

# %%
# Class exercise: Use filtering to show the trend in 2015 alone

# %% [markdown]
# ## Introduction to Autocorrelation

# %% [markdown]
# What is autocorrelation?
#
# Autocorrelation features measure the statistical correlation of a time series with a _lagged_ version of itself.
#
# **Check:** Why would we want to use autocorrelation? What are we trying to find?
#
# ### Computing Autocorrelation
# To measure how much the sales are correlated with each other, we want to compute the autocorrelation of the 'Sales' column. In pandas, we'll do this with the **autocorr** function.
#
#
# **Autocorr takes one argument**
#
# _the lag:_ how many prior data points should be used to compute the correlation.
#
# If we set the lag to 1, we compute the correlation between every point and the point directly preceding it, If we set lag to 10, this computes the correlation between every point  and the point 10 days earlier
#
# **Check:** How is correlation mesaured? What is the range of values?

# %%
data['Sales'].resample('D').mean().autocorr(lag=1)
# Out:
# -0.025858276006383588

# %%
#that's a pretty small mean correlation. what if we look at the autocorrelation for 30 days


data['Sales'].resample('D').mean().autocorr(lag=30)
# Out:
# -0.12984245822530618

# %%
#What value of lag would be best?

# %% [markdown]
# ### Resample
#
# If we want to investigate trends over time in sales, as always, we will start by computing simple aggregates. We want to know: what were the mean and median sales in each month and year?
#
# In Pandas, this is performed using the resample command, which is very similar to the groupby command. It allows us to group over different time intervals.
#
# We can use data.resample and provide as arguments: - The level on which to roll-up to, 'D' for day, 'W' for week, 'M' for month, 'A' for year - The aggregation to perform: 'mean', 'median', 'sum', etc.

# %%
data[['Sales']].resample('A').mean()
# Out:
#                   Sales
# Date
# 2013-12-31  5658.533675
# 2014-12-31  5833.290704
# 2015-12-31  5878.245380

# %%
data.resample('A').mean()    # whole dataframe
# Out:
#                  Store  DayOfWeek        Sales   Customers      Open  \
# Date
# 2013-12-31  557.998943   3.994525  5658.533675  629.043686  0.830380
# 2014-12-31  559.170379   3.998462  5833.290704  643.268034  0.830314
# 2015-12-31  558.000000   4.004717  5878.245380  624.199843  0.829309
#
#                Promo  SchoolHoliday    Year     Month
# Date
# 2013-12-31  0.369864       0.188774  2013.0  6.526041
# 2014-12-31  0.381913       0.186201  2014.0  6.263043
# 2015-12-31  0.400943       0.149264  2015.0  4.018868

# %%
data[['Sales']].resample('M').mean()
# Out:
#                   Sales
# Date
# 2013-01-31  5211.555578
# 2013-02-28  5494.371397
# 2013-03-31  5820.349168
# 2013-04-30  5483.749836
# 2013-05-31  5364.127383
# 2013-06-30  5402.162960
# 2013-07-31  6042.062260
# 2013-08-31  5729.574049
# 2013-09-30  5322.988430
# 2013-10-31  5429.258788
# 2013-11-30  5864.601614
# 2013-12-31  6703.618140
# 2014-01-31  5431.875799
# 2014-02-28  5731.091512
# 2014-03-31  5584.257312
# 2014-04-30  5815.993333
# 2014-05-31  5632.670534
# 2014-06-30  5681.526188
# 2014-07-31  5999.403381
# 2014-08-31  5649.421252
# 2014-09-30  5865.104029
# 2014-10-31  5665.564878
# 2014-11-30  6179.249661
# 2014-12-31  6973.282456
# 2015-01-31  5752.747866
# 2015-02-28  5710.296541
# 2015-03-31  5949.130132
# 2015-04-30  5916.857578
# 2015-05-31  5472.122002
# 2015-06-30  6199.203976
# 2015-07-31  6142.705511

# %%
# Resample to have the daily total over all stores
# Alternatively, this could a daily average over all store with how='mean'

daily_store_sales = data[['Sales']].resample('D').mean()
daily_store_sales.plot()

# %% [markdown]
# ### Applying the Rolling Mean
#
# What is a rolling mean, where might it be useful?
#
#
# We can use the pandas rolling_mean method to calculate the rolling mean.
#
# **Check**: Look at the documentation and tell us what "window" and "center" are

# %%
# 3-day rolling mean of daily store sales
pd.rolling_mean(daily_store_sales, window=3, center=True)
pd.rolling_mean(daily_store_sales, window=3, center=True)['2015']   # filter to 2015 only
pd.rolling_mean(daily_store_sales, window=10, center=True).plot()   # plot
# Out:
# /Users/elutins/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:3: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=3,center=True).mean()
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/elutins/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:4: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=3,center=True).mean()
#   after removing the cwd from sys.path.
# /Users/elutins/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:5: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=10,center=True).mean()
#   """

# %% [markdown]
# ### We can also use the exponentially weighted moving average.
#
# **Check:** What is the difference?

# %%
pd.ewma(data['Sales'], span=10)
# Out:
# /Users/elutins/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(ignore_na=False,span=10,min_periods=0,adjust=True).mean()
#   """Entry point for launching an IPython kernel.
# Date
# 2015-07-31    5.263000e+03
# 2015-07-31    5.703550e+03
# 2015-07-31    6.752934e+03
# 2015-07-31    9.138872e+03
# 2015-07-31    7.899615e+03
# 2015-07-31    7.315572e+03
# 2015-07-31    9.250101e+03
# 2015-07-31    9.077629e+03
# 2015-07-31    8.966099e+03
# 2015-07-31    8.591968e+03
# 2015-07-31    8.972971e+03
# 2015-07-31    8.970180e+03
# 2015-07-31    8.940900e+03
# 2015-07-31    8.477164e+03
# 2015-07-31    8.613681e+03
# 2015-07-31    8.920096e+03
# 2015-07-31    8.827947e+03
# 2015-07-31    9.060227e+03
# 2015-07-31    8.906611e+03
# 2015-07-31    9.033706e+03
# 2015-07-31    9.122527e+03
# 2015-07-31    8.652012e+03
# 2015-07-31    8.398776e+03
# 2015-07-31    9.460323e+03
# 2015-07-31    1.032417e+04
# 2015-07-31    9.866019e+03
# 2015-07-31    1.047727e+04
# 2015-07-31    9.897665e+03
# 2015-07-31    9.808917e+03
# 2015-07-31    8.891612e+03
#                   ...
# 2013-01-01    9.384395e-10
# 2013-01-01    7.678142e-10
# 2013-01-01    6.282116e-10
# 2013-01-01    5.139913e-10
# 2013-01-01    4.205383e-10
# 2013-01-01    3.440768e-10
# 2013-01-01    2.815174e-10
# 2013-01-01    2.303324e-10
# 2013-01-01    1.884538e-10
# 2013-01-01    1.541895e-10
# 2013-01-01    1.261550e-10
# 2013-01-01    1.083818e+03
# 2013-01-01    8.867603e+02
# 2013-01-01    7.255312e+02
# 2013-01-01    5.936164e+02
# 2013-01-01    4.856862e+02
# 2013-01-01    3.973796e+02
# 2013-01-01    3.251288e+02
# 2013-01-01    2.660144e+02
# 2013-01-01    2.176482e+02
# 2013-01-01    1.780758e+02
# 2013-01-01    1.456984e+02
# 2013-01-01    1.192078e+02
# 2013-01-01    9.753362e+01
# 2013-01-01    7.980023e+01
# 2013-01-01    6.529110e+01
# 2013-01-01    5.341999e+01
# 2013-01-01    4.370726e+01
# 2013-01-01    3.576049e+01
# 2013-01-01    2.925858e+01
# Name: Sales, Length: 1017209, dtype: float64

# %% [markdown]
# ## Other Window Functions
#
# Pandas rolling_mean and rolling_median are only two examples of Pandas window function capabilities. Window functions operate on a set of N consecutive rows (i.e.: a window) and produce an output. In addition to rolling_mean and rolling_median, there are rolling_sum, rolling_min, rolling_max... and many more.
#
# Another common one is **diff**, which takes the difference over time.
#
# **pd.diff** takes one argument: _periods_, which measures how many rows prior to use for the difference.
#
# For example, if we want to compute the difference in sales, day by day, we could compute:

# %%
daily_store_sales.diff(periods=1) # day by day difference in sales
daily_store_sales.diff(periods=7) # compare same day each week

# Difference functions allow us to identify seasonal changes when we see repeated up or downswings.
# An example from FiveThirtyEight:
# http://i2.wp.com/espnfivethirtyeight.files.wordpress.com/2015/03/casselman-datalab-wsj2.png?quality=90&strip=all&w=575&ssl=1
# Out:
#                   Sales
# Date
# 2013-01-01          NaN
# 2013-01-02          NaN
# 2013-01-03          NaN
# 2013-01-04          NaN
# 2013-01-05          NaN
# 2013-01-06          NaN
# 2013-01-07          NaN
# 2013-01-08  7759.744139
# 2013-01-09   714.595516
# 2013-01-10  1258.892377
# 2013-01-11  1255.921076
# 2013-01-12    59.101345
# 2013-01-13     0.132735
# 2013-01-14 -4430.547085
# 2013-01-15 -2903.000897
# 2013-01-16 -2200.522870
# 2013-01-17 -2121.005381
# 2013-01-18 -1706.095067
# 2013-01-19    -6.546188
# 2013-01-20     6.769507
# 2013-01-21  2577.834978
# 2013-01-22  2518.114798
# 2013-01-23  2200.486996
# 2013-01-24  1841.499552
# 2013-01-25  1474.241256
# 2013-01-26  -144.773094
# 2013-01-27    -7.849327
# 2013-01-28 -2585.086996
# 2013-01-29 -2571.857399
# 2013-01-30 -1647.339910
# ...                 ...
# 2015-07-02  2004.061883
# 2015-07-03  1700.180269
# 2015-07-04  -434.114798
# 2015-07-05     5.900448
# 2015-07-06 -3924.842152
# 2015-07-07 -4565.836771
# 2015-07-08 -1860.131839
# 2015-07-09 -1352.565919
# 2015-07-10 -1314.330942
# 2015-07-11   186.319283
# 2015-07-12     6.994619
# 2015-07-13  2960.353363
# 2015-07-14  2643.391031
# 2015-07-15  1650.683408
# 2015-07-16  1287.615247
# 2015-07-17   793.208969
# 2015-07-18   167.677130
# 2015-07-19    19.166816
# 2015-07-20 -3140.758744
# 2015-07-21 -2676.164126
# 2015-07-22 -2372.869058
# 2015-07-23 -1512.829596
# 2015-07-24 -1208.979372
# 2015-07-25  -383.243049
# 2015-07-26   -11.258296
# 2015-07-27  3020.601794
# 2015-07-28  2474.072646
# 2015-07-29  2143.115695
# 2015-07-30  1893.978475
# 2015-07-31  3146.562332
#
# [942 rows x 1 columns]

# %% [markdown]
# ## Pandas Expanding Functions
# In addition to the set of rolling functions, Pandas also provides a similar collection of expanding functions, which, instead of using a window of N values, uses all values up until that time.

# %%
pd.expanding_mean(daily_store_sales) # average date from first till last date specified
pd.expanding_sum(daily_store_sales) # sum of average sales per store until that date

#Check - what will these plots look like?
# Out:
# /Users/elutins/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: pd.expanding_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.expanding(min_periods=1).mean()
#   """Entry point for launching an IPython kernel.
# /Users/elutins/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:2: FutureWarning: pd.expanding_sum is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.expanding(min_periods=1).sum()
#                    Sales
# Date
# 2013-01-01  8.728456e+01
# 2013-01-02  6.320315e+03
# 2013-01-03  1.201343e+04
# 2013-01-04  1.796765e+04
# 2013-01-05  2.330540e+04
# 2013-01-06  2.343446e+04
# 2013-01-07  3.314464e+04
# 2013-01-08  4.099167e+04
# 2013-01-09  4.793929e+04
# 2013-01-10  5.489130e+04
# 2013-01-11  6.210144e+04
# 2013-01-12  6.749829e+04
# 2013-01-13  6.762748e+04
# 2013-01-14  7.290711e+04
# 2013-01-15  7.785114e+04
# 2013-01-16  8.259825e+04
# 2013-01-17  8.742924e+04
# 2013-01-18  9.293329e+04
# 2013-01-19  9.832360e+04
# 2013-01-20  9.845956e+04
# 2013-01-21  1.063170e+05
# 2013-01-22  1.137792e+05
# 2013-01-23  1.207268e+05
# 2013-01-24  1.273993e+05
# 2013-01-25  1.343775e+05
# 2013-01-26  1.396231e+05
# 2013-01-27  1.397512e+05
# 2013-01-28  1.450236e+05
# 2013-01-29  1.499139e+05
# 2013-01-30  1.552141e+05
# ...                  ...
# 2015-07-02  5.272519e+06
# 2015-07-03  5.280170e+06
# 2015-07-04  5.285600e+06
# 2015-07-05  5.285841e+06
# 2015-07-06  5.292604e+06
# 2015-07-07  5.298337e+06
# 2015-07-08  5.304540e+06
# 2015-07-09  5.310762e+06
# 2015-07-10  5.317099e+06
# 2015-07-11  5.322715e+06
# 2015-07-12  5.322963e+06
# 2015-07-13  5.332686e+06
# 2015-07-14  5.341063e+06
# 2015-07-15  5.348916e+06
# 2015-07-16  5.356427e+06
# 2015-07-17  5.363556e+06
# 2015-07-18  5.369340e+06
# 2015-07-19  5.369608e+06
# 2015-07-20  5.376190e+06
# 2015-07-21  5.381891e+06
# 2015-07-22  5.387371e+06
# 2015-07-23  5.393368e+06
# 2015-07-24  5.399289e+06
# 2015-07-25  5.404689e+06
# 2015-07-26  5.404946e+06
# 2015-07-27  5.414549e+06
# 2015-07-28  5.422724e+06
# 2015-07-29  5.430347e+06
# 2015-07-30  5.438238e+06
# 2015-07-31  5.447305e+06
#
# [942 rows x 1 columns]

# %% [markdown]
# # Review:
#
# We've covered a lot this afternoon. Let's review all of the terms and ideas we discussed:
#
# - Using datetime format in Pandas - Setting the index
# - Resampling
# - Autocorrelation
# - Window Functions
#     - Rolling Mean
#     - Explonential Mean
#     - Diff
# - Expanding Functions

# %% [markdown]
# ### EXERCISES
#
# 1. Plot the distribution of sales by month and compare the effect of promotions.
# hint: try using hue in sns
# 2. Are sales more correlated with the prior date, a similar date last year, or a similar date last month?
# 4. Identify the date with largest drop in sales from the same date in the previous week.
# 5. Compute the total sales up until Dec. 2014.
# 6. When were the largest differences between 15-day moving/rolling averages? HINT: Using rolling_mean and diff

# %%
# Plot the distribution of sales by month and compare the effect of promotions

# %%
# Are sales more correlated with the prior date, a similar date last year, or a similar date last month?

print "1 day lag correlation: " + str(data['Sales'].resample('D').mean().autocorr(lag=1*7))
print "30 day lag correlation: " + str(data['Sales'].resample('D').mean().autocorr(lag=4*7)) # looks at similar date last month
print "1 year lag correlation: " + str(data['Sales'].resample('D').mean().autocorr(lag=52*7))
# Out:
# 1 day lag correlation: 0.557489358874
# 30 day lag correlation: 0.718112116053
# 1 year lag correlation: 0.756613221965

# %%
# Identify the date with largest drop in average store sales from the same date in the previous month:

# %%
# Compute the total sales up until Dec. 2014:

# %%
# When were the largest differences between 15-day moving/rolling averages? HINT: Using rolling_mean and diff

# %% [markdown]
# #### Programming note on using time series for Capstones:
#
# Here's an example of using timeseries for a Capstone: https://github.com/samuel-stack/Portfolio/blob/master/Moving%20Violations%20VS.%20Speed%20Traps/Granger%20Causality%20test%20.ipynb
#
# Note, this Capstone makes use of Granger Causality: a statistical concept that says if a signal X "Granger-causes" (or "G-causes") a signal Y, then past values of X should contain information that helps predict Y above and beyond the information contained in past values of Y alone.
#
# To put it another way, a time series X1 is said to Granger-cause Y if the X1 values provide statistically significant information about future values of Y.
